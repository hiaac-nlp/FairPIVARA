# %%
# %pip install dataframe-image -q
# Out:
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %%
# https://cees-roele.medium.com/styling-complex-values-in-a-dataframe-7ebc5a17b3e7

# %%
max_value = 50
min_value = -50

# %%
cm = sns.light_palette("green", as_cmap=True)

# %%
def make_gradient(v, min_length, max_length, cmap):
    """
    Parameters
    ----------
    
    v: tuple of (word, length)
    min_length: int 
        minimum length of all words in the matrix
    max_length: int
        maximum length of all words in the matrix
    cmap: matplotlib color map, default value here is 'YlGn'
        
    Returns
    -------PRGn
    
    string:
        CSS setting a colour
              
    For Matplotlib colormaps:
    See: https://matplotlib.org/stable/tutorials/colors/colormaps.html
"""
    # normalize the word length as a fraction of the range 
    # between min_length and max_length
    rel_v = (v[1] - min_length) / (max_length - min_length)
    # define the colormap
    cmap = mpl.colormaps.get_cmap(cmap)
    # Get a colour out of the given colormap based on a value [0,1]
    rgba = cmap(rel_v)  
    # convert the colour to a hexadecimal string representation
    return f'background-color: {mpl.colors.rgb2hex(rgba)};'

# %%
def concatAndFormat(df1, df2, map):
    # #get the min value from all dataframe
    # min_value = 9999999999
    # max_value = -9999999999
    # for i in range(1,len(df1.values),2):
    #     if df1.iloc[i].astype(float).astype(int).min() < min_value:
    #         min_value = df1.iloc[i].astype(float).astype(int).min()
    #     if df1.iloc[i].astype(float).astype(int).max() > max_value:
    #         max_value = df1.iloc[i].astype(float).astype(int).max()

    df1_tuple = {}
    df2_tuple = {}
    list_of_super_concepts = ['Disability','Nationality','Religion','Sexual Orientation']
    list_of_super_concepts2 = ['Disability ','Nationality ','Religion ','Sexual Orientation ']
    list_of_concepts = ['Mental','Non','Physical','American','Arab','Chinese','Mexican','Buddhist','Christian','Hindu','Jewish','Muslim','Heterosexual','LGBT']
    concept = 0
    for i in range(0,len(list_of_concepts)*2,2):
        if concept < 3:
            super_concept = 0
        elif concept < 7:
            super_concept = 1
        elif concept < 12:
            super_concept = 2
        else:
            super_concept = 3
        df1_tuple[(list_of_super_concepts[super_concept],list_of_concepts[concept])] = list(zip(df1.iloc[i], df1.iloc[i+1].astype(float).astype(int)))
        if df2 is not None:
            df2_tuple[(list_of_super_concepts2[super_concept],list_of_concepts[concept])] = list(zip(df2.iloc[i], df2.iloc[i+1].astype(float).astype(int)))
        concept += 1
    
    df1 = pd.DataFrame(df1_tuple)
    df1 = df1.T
    if df2 is not None:
        df2 = pd.DataFrame(df2_tuple)
        df2 = df2.T
        df = pd.concat([df1,df2])
    else:
        df = df1
    df.style.format(lambda x: x[0])
    # We must apply both `format` and `applymap` to the DataFrame.style
    styler = df.style.format(lambda x: x[0])

    # min_length = df_values.min().min()
    # max_length = df_values.max().max()
    # styler.applymap(lambda x: make_gradient(x, min_value, max_value, sns.diverging_palette(10, 260, s=75, l=50, sep=1, n=9, center='light', as_cmap=True)))
    styler.applymap(lambda x: make_gradient(x, min_value, max_value, map))    
    styler.set_properties(**{'text-align': 'center'})
    styler.set_properties(**{'color': 'black'})
    display(styler)

    # Define the colormap
    gradient = np.linspace(0, 1, 256).reshape(1, -1)
    # Display the color palette
    plt.figure(figsize=(10, 0.2))
    plt.imshow(gradient, aspect='auto', cmap=map)
    plt.axis('off')
    plt.show()

# %%
my_map = sns.diverging_palette(10, 150, s=75, l=50, sep=1, n=9, center='light', as_cmap=True)

# %%
df1 = pd.read_csv('results/summary tables/Original Values/en-r0-originalvalue.csv')
df2 = pd.read_csv('results/summary tables/Original Values/br-r0-originalvalue.csv')

# df2 = pd.read_csv('results/summary tables/Original Values/en-r1-originalvalue.csv')
# df2 = pd.read_csv('results/summary tables/Original Values/br-r1-originalvalue.csv')

# df2 = None
concatAndFormat(df1,df2,my_map)
# Out:
# <style type="text/css">
# #T_8a671_row0_col0 {
#   background-color: #db424d;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row0_col1, #T_8a671_row13_col0 {
#   background-color: #dd505a;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row0_col2, #T_8a671_row2_col1 {
#   background-color: #de5761;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row0_col3, #T_8a671_row13_col1 {
#   background-color: #e16d75;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row0_col4, #T_8a671_row4_col1, #T_8a671_row9_col0, #T_8a671_row11_col1, #T_8a671_row13_col2, #T_8a671_row23_col0 {
#   background-color: #e37c84;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row0_col5, #T_8a671_row25_col0, #T_8a671_row25_col1 {
#   background-color: #e37f87;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row0_col6, #T_8a671_row1_col0, #T_8a671_row9_col1, #T_8a671_row14_col1 {
#   background-color: #e4838b;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row0_col7, #T_8a671_row1_col1, #T_8a671_row5_col1, #T_8a671_row11_col6, #T_8a671_row14_col4, #T_8a671_row27_col1 {
#   background-color: #e79a9f;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row0_col8, #T_8a671_row1_col2, #T_8a671_row2_col4, #T_8a671_row4_col2, #T_8a671_row15_col0, #T_8a671_row15_col1, #T_8a671_row16_col1 {
#   background-color: #e79ea3;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row0_col9, #T_8a671_row13_col4, #T_8a671_row14_col5, #T_8a671_row14_col6, #T_8a671_row14_col7 {
#   background-color: #e8a5aa;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row0_col10, #T_8a671_row1_col5, #T_8a671_row6_col3, #T_8a671_row12_col1, #T_8a671_row12_col2, #T_8a671_row16_col2, #T_8a671_row24_col2, #T_8a671_row25_col3 {
#   background-color: #e9acb1;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row0_col11, #T_8a671_row2_col6, #T_8a671_row4_col7, #T_8a671_row4_col8, #T_8a671_row9_col8, #T_8a671_row9_col9, #T_8a671_row10_col8 {
#   background-color: #a9c9bb;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row0_col12, #T_8a671_row1_col11, #T_8a671_row3_col10, #T_8a671_row3_col11, #T_8a671_row8_col8, #T_8a671_row12_col6, #T_8a671_row12_col7, #T_8a671_row13_col10, #T_8a671_row14_col14, #T_8a671_row15_col13, #T_8a671_row19_col13, #T_8a671_row26_col11, #T_8a671_row27_col13 {
#   background-color: #93bba9;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row0_col13 {
#   background-color: #629d83;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row0_col14, #T_8a671_row8_col14 {
#   background-color: #498d6f;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row1_col3, #T_8a671_row3_col3, #T_8a671_row10_col2, #T_8a671_row15_col2, #T_8a671_row20_col2 {
#   background-color: #e8a1a6;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row1_col4, #T_8a671_row2_col5, #T_8a671_row5_col2, #T_8a671_row6_col2, #T_8a671_row9_col2, #T_8a671_row10_col3, #T_8a671_row10_col4, #T_8a671_row10_col5, #T_8a671_row14_col8, #T_8a671_row14_col9, #T_8a671_row23_col1 {
#   background-color: #e9a8ad;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row1_

#   text-align: center;
#   color: black;
# }
# #T_8a671_row3_col5, #T_8a671_row3_col6, #T_8a671_row3_col7, #T_8a671_row5_col7, #T_8a671_row5_col8, #T_8a671_row7_col5, #T_8a671_row7_col6, #T_8a671_row7_col7, #T_8a671_row8_col5, #T_8a671_row9_col7, #T_8a671_row10_col7, #T_8a671_row16_col12, #T_8a671_row20_col12, #T_8a671_row23_col10, #T_8a671_row24_col12 {
#   background-color: #b0cdc0;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row3_col14, #T_8a671_row6_col14 {
#   background-color: #57967a;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row4_col0 {
#   background-color: #df5e68;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row4_col3, #T_8a671_row9_col3, #T_8a671_row11_col7, #T_8a671_row16_col3, #T_8a671_row20_col3 {
#   background-color: #eaafb3;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row4_col4, #T_8a671_row4_col5, #T_8a671_row5_col3, #T_8a671_row7_col2, #T_8a671_row13_col5, #T_8a671_row13_col6, #T_8a671_row14_col10, #T_8a671_row27_col2 {
#   background-color: #eab3b7;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row4_col6, #T_8a671_row6_col5, #T_8a671_row7_col4, #T_8a671_row8_col4, #T_8a671_row10_col6, #T_8a671_row20_col11, #T_8a671_row23_col9, #T_8a671_row24_col11 {
#   background-color: #b4d0c3;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row4_col11, #T_8a671_row4_col12, #T_8a671_row6_col9, #T_8a671_row7_col11, #T_8a671_row17_col14, #T_8a671_row18_col13, #T_8a671_row20_col14, #T_8a671_row21_col9 {
#   background-color: #97bead;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row5_col0, #T_8a671_row11_col5, #T_8a671_row14_col3 {
#   background-color: #e6979d;
#   text-align: center;
#   color: black;
# }
# #T_8a671_row5_col5, #T_8a671_row15_col7, #T_8a671_row15_col8, #T_8

# %%
df1 = pd.read_csv('results/summary tables/Mitigated Values/en-r0.csv')
df2 = pd.read_csv('results/summary tables/Original Values/en-r1-originalvalue.csv')
concatAndFormat(df1,df2,my_map)
# Out:
# <style type="text/css">
# #T_18d95_row0_col0, #T_18d95_row0_col1, #T_18d95_row0_col2, #T_18d95_row0_col3, #T_18d95_row0_col4, #T_18d95_row0_col5, #T_18d95_row0_col6, #T_18d95_row0_col7, #T_18d95_row0_col8, #T_18d95_row1_col0, #T_18d95_row1_col1, #T_18d95_row1_col2, #T_18d95_row1_col3, #T_18d95_row1_col4, #T_18d95_row1_col5, #T_18d95_row1_col6, #T_18d95_row1_col7, #T_18d95_row2_col0, #T_18d95_row2_col1, #T_18d95_row2_col2, #T_18d95_row2_col3, #T_18d95_row2_col4, #T_18d95_row2_col5, #T_18d95_row2_col6, #T_18d95_row2_col7, #T_18d95_row2_col8, #T_18d95_row3_col0, #T_18d95_row3_col1, #T_18d95_row3_col2, #T_18d95_row3_col3, #T_18d95_row3_col4, #T_18d95_row3_col5, #T_18d95_row3_col6, #T_18d95_row3_col7, #T_18d95_row4_col0, #T_18d95_row4_col1, #T_18d95_row4_col2, #T_18d95_row4_col3, #T_18d95_row4_col4, #T_18d95_row4_col5, #T_18d95_row4_col6, #T_18d95_row4_col7, #T_18d95_row5_col0, #T_18d95_row5_col1, #T_18d95_row5_col2, #T_18d95_row5_col3, #T_18d95_row5_col4, #T_18d95_row5_col5, #T_18d95_row5_col6, #T_18d95_row
95_row7_col12, #T_18d95_row7_col13, #T_18d95_row7_col14, #T_18d95_row8_col7, #T_18d95_row8_col8, #T_18d95_row8_col9, #T_18d95_row8_col10, #T_18d95_row8_col11, #T_18d95_row8_col12, #T_18d95_row8_col13, #T_18d95_row8_col14, #T_18d95_row9_col9, #T_18d95_row9_col10, #T_18d95_row9_col11, #T_18d95_row9_col12, #T_18d95_row9_col13, #T_18d95_row9_col14, #T_18d95_row10_col8, #T_18d95_row10_col9, #T_18d95_row10_col10, #T_18d95_row10_col11, #T_18d95_row10_col12, #T_18d95_row10_col13, #T_18d95_row10_col14, #T_18d95_row11_col8, #T_18d95_row11_col9, #T_18d95_row11_col10, #T_18d95_row11_col11, #T_18d95_row11_col12, #T_18d95_row11_col13, #T_18d95_row11_col14, #T_18d95_row12_col9, #T_18d95_row12_col10, #T_18d95_row12_col11, #T_18d95_row12_col12, #T_18d95_row12_col13, #T_18d95_row12_col14, #T_18d95_row13_col9, #T_18d95_row13_col10, #T_18d95_row13_col11, #T_18d95_row13_col12, #T_18d95_row13_col13, #T_18d95_row13_col14 {
#   background-color: #e9f1ed;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row14_col0, #T_18d95_row14_col1, #T_18d95_row14_col2, #T_18d95_row14_col3 {
#   background-color: #da3b46;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row14_col4, #T_18d95_row14_col5 {
#   background-color: #da3d49;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row14_col6, #T_18d95_row18_col0 {
#   background-color: #de5761;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row14_col7 {
#   background-color: #df5e68;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row14_col8, #T_18d95_row16_col1, #T_18d95_row25_col2 {
#   background-color: #e27880;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row14_col9, #T_18d95_row16_col5, #T_18d95_row25_col6, #T_18d95_row25_col7, #T_18d95_row27_col1 {
#   background-color: #e69298;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row14_col10, #T_18d95_row18_col3, #T_18d95_row18_col4 {
#   background-color: #e79a9f;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row14_col11, #T_18d95_row15_col1, #T_18d95_row16_col6, #T_18d95_row24_col7, #T_18d95_row25_col10, #T_18d95_row27_col2 {
#   background-color: #e8a1a6;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row14_col12, #T_18d95_row19_col1, #T_18d95_row24_col8 {
#   background-color: #e9a8ad;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row14_col13, #T_18d95_row15_col9, #T_18d95_row20_col13, #T_18d95_row27_col10 {
#   background-color: #a2c5b5;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row14_col14, #T_18d95_row26_col9, #T_18d95_row26_col10 {
#   background-color: #629d83;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row15_col0, #T_18d95_row24_col3, #T_18d95_row25_col3 {
#   background-color: #e4868d;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row15_col2, #T_18d95_row15_col3, #T_18d95_row16_col7, #T_18d95_row16_col8, #T_18d95_row20_col2, #T_18d95_row25_col11, #T_18d95_row27_col3 {
#   background-color: #e8a5aa;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row15_col4, #T_18d95_row15_col5, #T_18d95_row18_col9, #T_18d95_row19_col5, #T_18d95_row24_col10, #T_18d95_row26_col0, #T_18d95_row27_col5, #T_18d95_row27_col6 {
#   background-color: #ecbfc2;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row15_col6, #T_18d95_row19_col6 {
#   background-color: #bed6cb;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row15_col7, #T_18d95_row24_col11 {
#   background-color: #bbd4c9;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row15_col8, #T_18d95_row16_col12, #T_18d95_row17_col11, #T_18d95_row20_col9, #T_18d95_row20_col10, #T_18d95_row21_col1, #T_18d95_row21_col2, #T_18d95_row21_col3, #T_18d95_row26_col3 {
#   background-color: #accbbd;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row15_col10, #T_18d95_row15_col11, #T_18d95_row15_col12, #T_18d95_row16_col13, #T_18d95_row16_col14, #T_18d95_row24_col12, #T_18d95_row27_col11 {
#   background-color: #9ec2b2;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row15_col13, #T_18d95_row19_col14, #T_18d95_row22_col3, #T_18d95_row22_col4 {
#   background-color: #8bb7a3;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row15_col14 {
#   background-color: #6ba38a;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row16_col0 {
#   background-color: #de5b65;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row16_col2, #T_18d95_row18_col2, #T_18d95_row24_col2 {
#   background-color: #e37f87;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row16_col3, #T_18d95_row16_col4, #T_18d95_row24_col6, #T_18d95_row25_col5 {
#   background-color: #e58d94;
#   text-align: center;
#   color: black;
# }
# #T_18d95_row16_col9, #T_18d95_row21_col0 {

# %%
df1 = pd.read_csv('results/summary tables/Mitigated Values/br-r0.csv')
df2 = pd.read_csv('results/summary tables/Original Values/br-r1-originalvalue.csv')
concatAndFormat(df1,df2,my_map)
# Out:
# <style type="text/css">
# #T_c4dee_row0_col0, #T_c4dee_row4_col0, #T_c4dee_row5_col0, #T_c4dee_row5_col1, #T_c4dee_row6_col0, #T_c4dee_row6_col1, #T_c4dee_row7_col0, #T_c4dee_row8_col0, #T_c4dee_row8_col1, #T_c4dee_row9_col0, #T_c4dee_row9_col1, #T_c4dee_row9_col2, #T_c4dee_row10_col0, #T_c4dee_row12_col0 {
#   background-color: #f2eeee;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row0_col1, #T_c4dee_row0_col2, #T_c4dee_row0_col3, #T_c4dee_row0_col4, #T_c4dee_row0_col5, #T_c4dee_row0_col6, #T_c4dee_row0_col7, #T_c4dee_row0_col8, #T_c4dee_row0_col9, #T_c4dee_row0_col10, #T_c4dee_row0_col11, #T_c4dee_row0_col12, #T_c4dee_row0_col13, #T_c4dee_row0_col14, #T_c4dee_row1_col0, #T_c4dee_row1_col1, #T_c4dee_row1_col2, #T_c4dee_row1_col3, #T_c4dee_row1_col4, #T_c4dee_row1_col5, #T_c4dee_row1_col6, #T_c4dee_row1_col7, #T_c4dee_row1_col8, #T_c4dee_row1_col9, #T_c4dee_row1_col10, #T_c4dee_row1_col11, #T_c4dee_row1_col12, #T_c4dee_row1_col13, #T_c4dee_row1_col14, #T_c4dee_row2_col0, #T_c4dee_row2_col1, #T_c4dee_row2_col2, #T_c4dee_row2_col3, #T_c4dee_row2_col4, #T_c4dee_row2_col5, #T_c4dee_row2_col6, #T_c4dee_row2_col7, #T_c4dee_row2_col8, #T_c4dee_row2_col9, #T_c4dee_row2_col10, #T_c4dee_row2_col11, #T_c4dee_row2_col12, #T_c4dee_row2_col13, #T_c4dee_row2_col14, #T_c4dee_row3_col0, #T_c4dee_row3_col1, #T_c4dee_row3_col2, #T_c4dee_row3_col3, #T_c4dee_row3_col4, #T_c4dee_row3_col5, #T_c4dee_row3_col6, #T_c4dee_row3_col7, #T_c4dee_row3_col8, #T_c4dee_row3_col9, #T_c4dee_row3_col10, #T_c4dee_row3_col11, #T_c4dee_row3_col12, #T_c4dee_row3_col13, #T_c4dee_row3_col14, #T_c4dee_row4_col1, #T_c4dee_row4_col2, #T_c4dee_row4_col3, #T_c4dee_row4_col4, #T_c4dee_row4_col5, #T_c4dee_row4_col6, #T_c4dee_row4_col7, #T_c4dee_row4_col8, #T_c4dee_row4_col9, #T_c4dee_row4_col10, #T_c4dee_row4_col11, #T_c4dee_row4_col12, #T_c4dee_row4_col13, #T_c4dee_row4_col14, #T_c4dee_row5_col2, #T_c4dee_row5_col3, #T_c4dee_row5_col4, #T_c4dee_row5_col5, #T_c4dee_row5_col6, #T_c4dee_row5_col7, #T_c4dee_row5_col8, #T_c4dee_row5_col9, #T_c4dee_row5_col10, #T_c4dee_row5_col11, #T_c4dee_row5_col12, #T_c4dee_row5_col13, #T_c4dee_row5_col14, #T_c4dee_row6_col2, #T_c4dee_row6_col3, #T_c4dee_row6_col4, #T_c4dee_row6_col5, #T_c4dee_row6_col6, #T_c4dee_row6_col7, #T_c4dee_row6_col8, #T_c4dee_row6_col9, #T_c4dee_row6_col10, #T_c4dee_row6_col11, #T_c4dee_row6_col12, #T_c4dee_row6_col13, #T_c4dee_row6_col14, #T_c4dee_row7_col1, #T_c4dee_row7_col2, #T_c4dee_row7_col3, #T_c4dee_row7_col4, #T_c4dee_row7_col5, #T_c4dee_row7_col6, #T_c4dee_row7_col7, #T_c4dee_row7_col8, #T_c4dee_row7_col9, #T_c4dee_row7_col10, #T_c4dee_row7_col11, #T_c4dee_row7_col12, #T_c4dee_row7_col13, #T_c4dee_row7_col14, #T_c4dee_row8_col2, #T_c4dee_row8_col3, #T_c4dee_row8_col4, #T_c4dee_row8_col5, #T_c4dee_row8_col6, #T_c4dee_row8_col7, #T_c4dee_row8_col8, #T_c4dee_row8_col9, #T_c4dee_row8_col10, #T_c4dee_row8_col11, #T_c4dee_row8_col12, #T_c4dee_row8_col13, #T_c4dee_row9_col3, #T_c4dee_row9_col4, #T_c4dee_row9_col5, #T_c4dee_row9_col6, #T_c4dee_row9_col7, #T_c4dee_row9_col8, #T_c4dee_row9_col9, #T_c4dee_row9_col10, #T_c4dee_row9_col11, #T_c4dee_row9_col12, #T_c4dee_row9_col13, #T_c4dee_row9_col14, #T_c4dee_row10_col1, #T_c4dee_row10_col2, #T_c4dee_row10_col3, #T_c4dee_row10_col4, #T_c4dee_row10_col5, #T_c4dee_row10_col6, #T_c4dee_row10_col7, #T_c4dee_row10_col8, #T_c4dee_row10_col9, #T_c4dee_row10_col10, #T_c4dee_row10_col11, #T_c4dee_row10_col12, #T_c4dee_row10_col13, #T_c4dee_row10_col14, #T_c4dee_row11_col0, #T_c4dee_row11_col1, #T_c4dee_row11_col2, #T_c4dee_row11_col3, #T_c4dee_row11_col4, #T_c4dee_row11_col5, #T_c4dee_row11_col6, #T_c4dee_row11_col7, #T_c4dee_row11_col8, #T_c4dee_row11_col9, #T_c4dee_row11_col10, #T_c4dee_row11_col11, #T_c4dee_row11_col12, #T_c4dee_row11_col13, #T_c4dee_row11_col14, #T_c4dee_row12_col1, #T_c4dee_row12_col2, #T_c4dee_row12_col3, #T_c4dee_row12_col4, #T_c4dee_row12_col5, #T_c4dee_row12_col6, #T_c4dee_row12_col7, #T_c4dee_row12_col8, #T_c4dee_row12_col9, #T_c4dee_row12_col10, #T_c4dee_row12_col11, #T_c4dee_row12_col12, #T_c4dee_row12_col13, #T_c4dee_row12_col14, #T_c4dee_row13_col0, #T_c4dee_row13_col1, #T_c4dee_row13_col2, #T_c4dee_row13_col3, #T_c4dee_row13_col4, #T_c4dee_row13_col5, #T_c4dee_row13_col6, #T_c4dee_row13_col7, #T_c4dee_row13_col8, #T_c4dee_row13_col9, #T_c4dee_row13_col10, #T_c4dee_row13_col11, #T_c4dee_row13_col12, #T_c4dee_row13_co ...
#   background-color: #eff2f0;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row8_col14 {
#   background-color: #e9f1ed;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row14_col0 {
#   background-color: #de5761;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row14_col1 {
#   background-color: #df636c;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row14_col2 {
#   background-color: #e16d75;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row14_col3, #T_c4dee_row25_col0 {
#   background-color: #e4868d;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row14_col4, #T_c4dee_row14_col5, #T_c4dee_row17_col0 {
#   background-color: #e58d94;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row14_col6 {
#   background-color: #e8a1a6;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row14_col7, #T_c4dee_row19_col1, #T_c4dee_row20_col2, #T_c4dee_row24_col3, #T_c4dee_row24_col4 {
#   background-color: #eaafb3;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row14_col8, #T_c4dee_row14_col9, #T_c4dee_row18_col3, #T_c4dee_row18_col4, #T_c4dee_row20_col3, #T_c4dee_row27_col2 {
#   background-color: #eab3b7;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row14_col10, #T_c4dee_row16_col1, #T_c4dee_row17_col2, #T_c4dee_row20_col4, #T_c4dee_row21_col0, #T_c4dee_row24_col5, #T_c4dee_row24_col6, #T_c4dee_row25_col3, #T_c4dee_row25_col4, #T_c4dee_row27_col3 {
#   background-color: #ebb8bb;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row14_col11, #T_c4dee_row18_col5, #T_c4dee_row19_col2, #T_c4dee_row20_col5, #T_c4dee_row22_col1, #T_c4dee_row24_col7, #T_c4dee_row25_col5 {
#   background-color: #ebbbbe;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row14_col12, #T_c4dee_row15_col4, #T_c4dee_row15_col5, #T_c4dee_row16_col11, #T_c4dee_row17_col9, #T_c4dee_row18_col11, #T_c4dee_row18_col12, #T_c4dee_row19_col7, #T_c4dee_row20_col10, #T_c4dee_row21_col3, #T_c4dee_row24_col11, #T_c4dee_row25_col11, #T_c4dee_row26_col3 {
#   background-color: #bed6cb;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row14_col13, #T_c4dee_row15_col11, #T_c4dee_row17_col10, #T_c4dee_row17_col11, #T_c4dee_row18_col13, #T_c4dee_row23_col10 {
#   background-color: #a9c9bb;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row14_col14, #T_c4dee_row23_col11 {
#   background-color: #9ec2b2;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row15_col0 {
#   background-color: #e9acb1;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row15_col1, #T_c4dee_row17_col4, #T_c4dee_row17_col5, #T_c4dee_row23_col1, #T_c4dee_row24_col9, #T_c4dee_row24_col10, #T_c4dee_row25_col8 {
#   background-color: #edc6c9;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row15_col2, #T_c4dee_row16_col3, #T_c4dee_row16_col4, #T_c4dee_row16_col5, #T_c4dee_row18_col8, #T_c4dee_row20_col7, #T_c4dee_row25_col9 {
#   background-color: #eecdcf;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row15_col3, #T_c4dee_row16_col10, #T_c4dee_row18_col10, #T_c4dee_row19_col5, #T_c4dee_row19_col6, #T_c4dee_row20_col9, #T_c4dee_row21_col2, #T_c4dee_row22_col2, #T_c4dee_row25_col10, #T_c4dee_row27_col6, #T_c4dee_row27_col7, #T_c4dee_row27_col8 {
#   background-color: #c2d9ce;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row15_col6, #T_c4dee_row16_col12, #T_c4dee_row19_col8, #T_c4dee_row19_col9, #T_c4dee_row21_col4, #T_c4dee_row23_col4, #T_c4dee_row24_col12 {
#   background-color: #bbd4c9;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row15_col7, #T_c4dee_row20_col11, #T_c4dee_row21_col5, #T_c4dee_row27_col9, #T_c4dee_row27_col10 {
#   background-color: #b7d2c6;
#   text-align: center;
#   color: black;
# }
# #T_c4dee_row15_col8, #T_c4dee_row15_col9, #T

# %%
df1 = pd.read_csv('results/summary tables/Mitigated Values/br-r0.csv')
df2 = pd.read_csv('results/summary tables/Original Values/br-r1-originalvalue.csv')
concatAndFormat(df1,df2,sns.cubehelix_palette(start=.5, rot=-.5, as_cmap=True))
# Out:
# <style type="text/css">
# #T_eac08_row0_col0, #T_eac08_row4_col0, #T_eac08_row5_col0, #T_eac08_row5_col1, #T_eac08_row6_col0, #T_eac08_row6_col1, #T_eac08_row7_col0, #T_eac08_row8_col0, #T_eac08_row8_col1, #T_eac08_row9_col0, #T_eac08_row9_col1, #T_eac08_row9_col2, #T_eac08_row10_col0, #T_eac08_row12_col0 {
#   background-color: #6687ac;
#   text-align: center;
#   color: black;
# }
# #T_eac08_row0_col1, #T_eac08_row0_col2, #T_eac08_row0_col3, #T_eac08_row0_col4, #T_eac08_row0_col5, #T_eac08_row0_col6, #T_eac08_row0_col7, #T_eac08_row0_col8, #T_eac08_row0_col9, #T_eac08_row0_col10, #T_eac08_row0_col11, #T_eac08_row0_col12, #T_eac08_row0_col13, #T_eac08_row0_col14, #T_eac08_row1_col0, #T_eac08_row1_col1, #T_eac08_row1_col2, #T_eac08_row1_col3, #T_eac08_row1_col4, #T_eac08_row1_col5, #T_eac08_row1_col6, #T_eac08_row1_col7, #T_eac08_row1_col8, #T_eac08_row1_col9, #T_eac08_row1_col10, #T_eac08_row1_col11, #T_eac08_row1_col12, #T_eac08_row1_col13, #T_eac08_row1_col14, #T_eac08_row2_col0, #T_eac08_row2_col1, #T_eac08_row2_col2, #T_eac08_row2_col3, #T_eac08_row2_col4, #T_eac08_row2_col5, #T_eac08_row2_col6, #T_eac08_row2_col7, #T_eac08_row2_col8, #T_eac08_row2_col9, #T_eac08_row2_col10, #T_eac08_row2_col11, #T_eac08_row2_col12, #T_eac08_row2_col13, #T_eac08_row2_col14, #T_eac08_row3_col0, #T_eac08_row3_col1, #T_eac08_row3_col2, #T_eac08_row3_col3, #T_eac08_row3_col4, #T_eac08_row3_col5, #T_eac08_row3_col6, #T_eac08_row3_col7, #T_eac08_row3_col8, #T_eac08_row3_col9, #T_eac08_row3_col10, #T_eac08_row3_col11, #T_eac08_row3_col12, #T_eac08_row3_col13, #T_eac08_row3_col14, #T_eac08_row4_col1, #T_eac08_row4_col2, #T_eac08_row4_col3, #T_eac08_row4_col4, #T_eac08_row4_col5, #T_eac08_row4_col6, #T_eac08_row4_col7, #T_eac08_row4_col8, #T_eac08_row4_col9, #T_eac08_row4